# %% [markdown]
# **Источники:**
# 1. [x] [**Нетология**: Основы веб-аналитики для интернет-маркетологов](https://netology.ru/profile/program/aim-bp2)
# 2. [**Нетология**: Старт в таргетированной и контекстной рекламе](https://netology.ru/profile/program/tkrfree-1)
# 3. [**Нетология**: Маркетинговая воронка: как повысить продажи](https://netology.ru/profile/program/mdfree)
# 4. [**Яндекс.Практикум**: Основы статистики и A/B-тестирования](https://practicum.yandex.ru/profile/statistics-basic/?from=new_landing_statistics-basic)
# 5. [**НЕПрактикум**: Яндекс для предпринимателей](https://yandex.ru/adv/edu/online/smb-dlya-predprinimateley-kurs?utm_source=metrika_support_popup&utm_medium=web&utm_campaign=static&utm_content=useful_links)
# 6. [**НЕПрактикум**: Как продвигать товары в интернете: владельцам интернет-магазинов](https://yandex.ru/adv/edu/online/kurs-prodvizhenie?utm_source=metrika_support_popup&utm_medium=web&utm_campaign=static&utm_content=useful_links)
# 7. [**Skillbox**: Введение в аналитику](https://skillbox.ru/course/introduction-to-analytics-free/)
# 8. [Сертификация специалистов по Яндекс Метрике](https://yandex.ru/adv/expert/exam/metrika?utm_source=metrika_help&utm_medium=web&utm_campaign=static&utm_content=useful_links)
# 9. [Материалы для подготовки к сертификации по Метрике](https://yandex.ru/adv/expert/materials/metrika#ch1)
# 10. [Документация Яндекс.Метрики](https://yandex.ru/support/metrica/index.html)
# 11. [Яковлев, А. Веб-аналитика: основы, секреты, трюки](https://cloudflare-ipfs.com/ipfs/bafykbzacebkfgwvggd4ueg4ttn42jw75k5df3ru66w7pnokxyiwvjsg2cmdo6?filename=%D0%AF%D0%BA%D0%BE%D0%B2%D0%BB%D0%B5%D0%B2%20%D0%90.%2C%20%D0%94%D0%BE%D0%B2%D0%B6%D0%B8%D0%BA%D0%BE%D0%B2%20%D0%90.%20-%20%D0%92%D0%B5%D0%B1-%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA%D0%B0%20%20%D0%BE%D1%81%D0%BD%D0%BE%D0%B2%D1%8B%2C%20%D1%81%D0%B5%D0%BA%D1%80%D0%B5%D1%82%D1%8B%2C%20%D1%82%D1%80%D1%8E%D0%BA%D0%B8-%D0%91%D0%A5%D0%92-%D0%9F%D0%B5%D1%82%D0%B5%D1%80%D0%B1%D1%83%D1%80%D0%B3%2C%20%282010%29.pdf)
# 12. [Google Analytics Individual Qualification](https://skillshop.exceedlms.com/student/path/2938-google-analytics-individual-qualification)
# 13. [Профессиональная сертификация 'Google Data Analytics'](https://www.coursera.org/professional-certificates/google-data-analytics)
# 14. [Сертификации Google](https://skillshop.exceedlms.com/student/page/998745-certifications?navlink=true)
# 15. [Сертификации Microsoft](https://learn.microsoft.com/en-us/credentials/browse/?credential_types=certification)
# 16. [Яндекс открывает ClickHouse](https://habr.com/ru/companies/yandex/articles/303282/)

# %% [markdown]
# **Полезные ссылки:**
# * [10 вопросов маркетологу: может ли маркетинг спасти плохой продукт, почему маркетологам важно иметь чувство стиля и вкуса, сложно ли попасть в выпуск Юрия Дудя](https://netology.ru/blog/12-2021-marketolog-faq)
# * [ТОП-15 актуальных трендов интернет-маркетинга для России: эксперт рассказал о тенденциях рынка в 2022 году](https://vc.ru/marketing/451683-top-15-aktualnyh-trendov-internet-marketinga-dlya-rossii-ekspert-rasskazal-o-tendenciyah-rynka-v-2022-godu)
# * [Какой контент выпускать в новых реалиях: ситуативный маркетинг, инфоповоды и переупаковка материалов](https://netology.ru/blog/08-2022-anti-crisis-content)
# * [Веб-аналитика: основные термины ](https://room42.ru/web-analytics-terms)
# * [22 способа найти информацию о целевой аудитории](https://vc.ru/marketing/80538-22-sposoba-nayti-informaciyu-o-celevoy-auditorii)
# * [Как объяснить дедушке веб-аналитику за 5 минут с картинками](https://webpromoexperts.net/blog/kak-obyasnit-dedushke-veb-analitiku-za-5-minut-s-kartinkami-2/)
# * [Знакомство с Google Analytics для новичков](https://netology.ru/blog/google-analytics-new)
# * [Обзор Яндекс Метрики](https://www.youtube.com/watch?v=ZbRV6TszWA8&list=PLjEKjSpX1kHVzQ7VT3shbWbYkXV2ac9Jo)
# * [Тренды веб-аналитики в 2022 году](https://metrika-analytics.ru/analysis/trendy-web-analysis-2022/)
# * [33 метрики digital-маркетинга, которые всегда актуальны](https://blog.ingate.ru/detail/33-metriki-digital-marketinga-kotorye-vsegda-aktualny/)
# * [Что такое юзабилити и как его улучшить](https://practicum.yandex.ru/blog/chto-takoe-usability-sayta/)
# * [Калькулятор достоверности АB-тестирования](https://mindbox.ru/tools/ab-test-calculator/)
# * [Из гуманитария в веб-аналитики](https://www.seonews.ru/analytics/iz-novostnogo-redaktora-v-veb-analitiki-mozhno-li-perestat-byt-gumanitariem/)

# %% [markdown]
# # Введение

# %% [markdown]
# **Базовый глоссарий маркетолога**
# * **Веб-аналитика** – сбор, измерение, представление, количественный и качественный анализ информации о посетителях интернет-ресурсов (их поведение на сайтах). Получаемые данные используются для улучшения и оптимизации сайтов с целью расширения их функциональных возможностей, а также для более эффективного расходования рекламных бюджетов.
# * **Интернет-канал** – ресурс или сервис источника рекламы, с которого приходит целевая аудитория. Например: источник — Яндекс, а канал — контекстная реклама Яндекс.Директ.
# * **Клик** – нажатие пользователем на ссылку или баннер.
# * **Коллтрекинг** – мониторинг звонков, совершённых после показа рекламы, в основе которого лежит подмена телефонных номеров.
# * **Конверсия** – доля сеансов, в которых пользователи выполнили целевое действие от общего количества сеансов за отчётный период.
# * **Лид** (от англ.*lead* – вести) – потенциальный клиент, тем или иным образом отреагировавший на маркетинговую коммуникацию.
# * **Охват** – количество человек, проконтактировавших с рекламным сообщением хотя бы один раз в течение рассматриваемого периода.
# * **Парсер** – скрипт или программа, используемые для сбора информации с сайтов.
# * **Поисковая оптимизация** – комплекс мер для поднятия позиций сайта в результатах выдачи поисковых систем по определённым запросам пользователей. В подобные меры входит: работа с контентом, мета-тегами, заголовками сайта, создание и работе со ссылочной массой.
# * **Показы** – появления вашего объявления на страницах, загружаемых пользователями.
# * **Рекламная кампания** – комплекс мероприятий, направленных на онлайн-рекламу товаров и услуг компании. Рекламная кампания в интернете состоит из медиапланирования, проведения кампании (с коррекцией плана по мере необходимости) и оценки результатов.
# * **Ставка** – цена клика, которую готов заплатить рекламодатель. Ставка может равняться минимальной цене клика, но не может быть меньше её.
# * **Таргетинг** – рекламный механизм, с помощью которого из общей аудитории выделяют целевую группу пользователей, соответствующую заданным критериям, и показывают рекламу именно этой группе.
# * **Трафик** (англ. *traffic* — движение, транспорт). В контексте интернет-маркетинга означает объём посетителей сайта за отчётный период. Измеряется чаще всего в количестве визитов на сайт.
# * **Data-driven** (англ. управляемый данными) – подход к управлению, который основывается на собираемых данных.
# * **KPI** – ключевые показатели эффективности, используемые для измерения поставленных перед компанией целей в социальных сетях.
# * **LTV (Lifetime Value)** – прибыль, которую приносит пользователь за всё время работы с ним, «жизненный цикл» клиента.
# * **ROI (Return On Investment)** – коэффициент рентабельности инвестиций, который выражается в процентах дохода на каждый вложенный рубль. Чем выше показатель, тем выше уровень возврата инвестированных средств. ROI = (доход – сумма инвестиций) ÷ количество вложенных средств × 100%.

# %% [markdown]
# **Целевая аудитория** — это объединённая общими признаками группа людей, заинтересованных в товарах или услугах компании. Под общими признаками могут пониматься любые характеристики (не только пол, возраст), необходимые компании для продвижения своего продукта (например, работающие замужние женщины от 25 до 35 лет, носящие очки). Именно на них в первую очередь направлена маркетинговая активность.

# %% [markdown]
# **Нужно ли сегментировать аудиторию для эффективной работы рекламы?** \
# Да. Когда мы сегментируем аудиторию и подбираем более персонализированное предложение для решения задачи конкретных пользователей, то можем увеличить количество продаж и средний чек. Более того, аудитория, как правило, неоднородна, с разной мотивацией к покупке, а значит, для разных сегментов будут актуальны разные УТП (уникальные торговые предложения).

# %% [markdown]
# **Уникальное торговое предложение** — это характеристика товара или бренда, которая выделяет его на фоне конкурентов и на основании которой выстраивается маркетинговая коммуникация. \
# никальное торговое предложение (УТП) — это характеристика, позволяющая продукту, услуге или бренду выгодно отличаться от конкурентов. Часто УТП используется для отстройки от конкурентов: подчёркивается собственное преимущество, которым конкурент не обладает.

# %% [markdown]
# **Как понять, что интернет-реклама работает хорошо?** \
# От рекламы мы ждём новых продаж, но важно, чтобы она работала «в плюс», чтобы доходы от неё покрывали расходы.
# Во время проведения рекламных кампаний необходимо отслеживать, сколько мы тратим за один переход по рекламе, за привлечение одного покупателя; не выходят ли эти показатели за предельно допустимые — те, которые мы можем себе позволить. Важно мониторить отмеченные показатели постоянно, не только на старте кампании.
# Это позволит вовремя корректировать рекламные настройки и предложения для клиентов.

# %% [markdown]
# **Как нам выяснить, много ли пользователей приходит на наш сайт благодаря рекламным кампаниям и каковы источники трафика?** (Мы не знаем, сколько пользователей появляется на сайте каждый день, да ещё и в разбивке по разным кампаниям.) \
# Необходимо установить счётчики систем аналитики.
# установка счётчиков Яндекс Метрики и Google Аналитики поможет нам понять, какое количество пользователей приходит на сайт каждый день, откуда они приходят, какие действия совершают.
#
# В системах аналитики мы сможем анализировать данные в разных срезах, таких как источники перехода пользователей, рекламные кампании. Для оценки эффективности работы источников мы настроим нужные цели и будем сравнивать источники друг с другом.
# Счётчики аналитики также помогут нам установить, каков пол и возраст нашей целевой аудитории, из каких регионов и городов чаще совершаются покупки. Кроме того, мы сможем проанализировать поведение пользователей и построить воронку продаж.

# %% [markdown]
# **Каждое ли действие пользователя на сайте можно отследить?** \
# При умелой настройке можно отслеживать практически любое действие пользователя на сайте: посещение разных страниц, добавление товаров в корзину, их оформление и покупку, заполнение и отправку форм и т.п.

# %% [markdown]
# **Воронка продаж** — путь, который пользователь проходит до покупки. Каждый шаг, который совершает пользователь на пути к покупке — это шаг в воронке продаж. Воронку важно уметь строить и анализировать, так как её исследование помогает находить точки роста для увеличения продаж, а также прогнозировать нужный объём трафика.

# %% [markdown]
# # Цели и задачи веб-аналитики

# %% [markdown]
# **Веб-аналитика** - это сбор и последующий анализ данных в интернет-маркетинге.
#
# **Цель веб-аналитики**: анализ ресурса и каналов привлечения трафика для последующего улучшения самого ресурса и оптимизации каналов трафика.
#
# **Задачи веб-аналитики**:
# * Улучшить ресурс: сайт, мобильное приложение, сервис. Мы смотрим на сайт через призму клиентов.
# * Оценить качество трафика: В первую очередь платного трафика.
# * Исключить субъективность: и лучше понять свою аудиторию.
# * Оптимизировать продуктовую линейку или услуги: Больше инсайтов про то, что ЦА готова купить в интернете.
#
# **Веб-аналитика не спасет, если...:**
# * Мало данных. Например, в день приходят 10 пользователей на сайт, по каналу за месяц получили 2 конверсии, за неделю 6 установок приложений.
# * Некорректно оцениваются насыщение конверсии: Если уже все хорошо, то скачка в 2 раза и более не получить.
# * Данные не корректны.
# * Нет связи между действиями в интернете и бизнес-показателями: Отдельно считаются клики на рекламу, отдельно продажи.

# %% [markdown]
# # Данные веб-аналитики

# %% [markdown]
# **3 состояния данных веб-аналитики**:
# 1. Мало данных. На этом этапе обычно приходят к осознанию недостаточности информации для принятия решений. Это обычно какой-нибудь стартап или начальная стадия интернет-компании. Начинается корректная настройка сбора информации.
# 2. Достаточное количество информации. Рождается множество табличных и дашбордов, и порой много информации собирается бесполезно. Мы начинаем оптимизировать время и состредоточение ресурсов.
# 3. Большой объем данных. Data driven. Как правильно собирать, хранить и обрабатывать весь массив данных, чтобы это приносило пользу и окупало затраты.

# %% [markdown]
# **Какие данные мы можем собирать в рамках веб-аналитики:**
# * Показы материалов аудитории. Это самый верхний уровень информации
# * Объем трафика.
# * Понять ЦА (пол, возраст, другие демографические показатели и индикаторы их предпочтений). Нужно для таргетирования
# * Источники трафика.
# * Качество трафика. Уровень вовлечения в контент.
# * Целевые действия (заказы, заявки с сайта и пр.)

# %% [markdown]
# **Понятия качества трафика**:
# 1. **Отказы** - доля пользователей, которые закрыли сайт в течение первых 15 секунд, проведенных на нем. Причины: (1) долгая загрузка сайта, (2) сайт не адаптирован под устройство, (3) юзеру не интересен продукт. Оптимальное количество отказов - 20-30%.
# 2. **Время на сайте** - показатель, который отмечает, сколько времени пользователи (в среднем) проводят на сайте. Универсального оптимального показателя тут нет. В среднем нужно полторы минуты, чтобы совершить целевое действие. С какого-то канала приходят пользователи со среднем временем на 30 секунд.
# 3. **Глубина просмотра** - это среднее количество просмотренных страниц одним пользователем за сеанс. Также нет универсального показателя.

# %% [markdown]
# # Метрики и бизнес-показатели

# %% [markdown]
# **Типы метрик**:
# 1. Данные по сайту
#     * Визиты
#     * Показатель отказов
#     * Глубина просмотров
#     * Время на сайте
#     * Уровень вовлеченности
#     * Новые и вернувшиеся пользователи
# 2. Данные по конверсии
#     * Стоимость конверсии (какое количество рекламных расходов на 1 целевое действие)
#     * Доход с каждого клика по рекламе
#     * Средняя стоимость продажи с сайта
#     * Возвращение затрат на рекламу с конкретного рекламного канала
# 3. Бизнес-показатели (чем интересуется заказчик, владелец бизнеса)
#     * Окупаемость инвестиций на рекламу
#     * LTV (доход с клиента за все время взаимодействия с ним).
#     * Средний чек
#     * Коэффициент закрытия лидов (лиды - это тот, который указал свои контактные данные)
#     * Коэффициент удержания клиентов
#     * Частота покупок
#     * Частота повторных покупок

# %% [markdown]
# # Практика веб-аналитики

# %% [markdown]
# ![imвуавпеауцфваыфвыпвage.png](attachment:image.png)

# %% [markdown]
# Стоимость лида в первом случае ниже. У нас 10.000 рублей, тогда в мы получим 20 лидов в первом случае и 10 лидов во втором случае.

# %% [markdown]
# ![iывапаввцааавцувыуыmage.png](attachment:image.png)

# %% [markdown]
# Кажется, что источник 1 более привлекателен (стоимость лидов ниже, а доля целевых заявок выше).

# %% [markdown]
# ![imцуацуквпацвыапыуфкыage.png](attachment:image.png)

# %% [markdown]
# Конверсия из заявки в продажу (CR) выше во втором случае. Теперь мы видим, что второй источник трафика приносит нам бОльшую конверсию.

# %% [markdown]
# Нам нужно сильно больше данных, чтобы бизнес зарабатывал, а не просто получал заявки с сайтов.

# %% [markdown]
# # Алгоритм анализа данных и выводы

# %% [markdown]
# ![iцуыкауцфыакуыквmage.png](attachment:image.png)

# %% [markdown]
# # Квиз

# %% [markdown]
# **Как можно обозначать конверсию?**
# * **Conversion rate (CR)** — конверсия, отношение числа посетителей сайта, выполнивших на нём какие-либо целевые действия, к общему количеству посетителей сайта.
#
# Но термин часто используется и для обозначения количества пользователей, перешедших с одного этапа воронки на другой. Например, у нас такая воронка: зашли на сайт — посмотрели условия доставки — положили товар в корзину — оформили заказ.Тогда будет конверсия из посетителей сайта — в перешедших на страницу доставки, из перешедших на страницу доставки — в положивших товар в корзину и т. д.
#
# Для удобства в отчётах такие конверсии могут обозначать **C1**, **C2**, **C3** и т. д. (в зависимости от количества этапов в воронке). С0 будет обозначать сквозную конверсию — из первого этапа в последний.
#
# **CTR** — тоже конверсия, но обозначает конкретный этап — отношение количества кликнувших на баннер или рекламное объявление к увидевшим.

# %% [markdown]
# ![iуыуцЦЫФцфуаыmage.png](attachment:image.png)

# %% [markdown]
# Рассчитайте количество кликов по баннеру, чтобы установить, какое количество пользователей перешли на сайт благодаря баннеру.
# ![imауфвцыфвыаыафваыпage.png](attachment:image.png)

# %% [markdown]
# **Вычислите drop-off rate.** \
# **Drop-off rate** — это процент выходов. В данном случае это пользователи, которые кликнули на баннер, но не перешли на сайт, закрыли его.
#
# Причины могут быть разные. Первая — сайт долго грузился: с увеличением загрузки сайта до 5 секунд показатель отказов увеличивается до 90%.
# Вторая — пользователи случайно кликнули по рекламе.
# Третья — реклама вводит пользователя в заблуждение, например, «крестик», обычно обозначающий возможность закрыть рекламу, оказался элементом картинки, а кнопка «Закрыть» была спрятана.
#
# Деньги при этом списываются за клик, поэтому важно знать drop-off rate.
#
# Процент выходов позволяет нам понимать, есть ли проблемы с сайтом, отвечает ли рекламное объявление ожиданиям пользователя. Так как каждый клик по рекламному объявлению оплачивается из нашего рекламного бюджета, то необходимо следить за работой сайта, отвечает ли объявление запросу целевой аудитории, ведёт ли оно на нужную страницу.
# ![imыцвапавываввцage.png](attachment:image.png)

# %% [markdown]
# **Какой процент пользователей конвертировался из бесплатного продукта в платный? Какой процент «отвалился»?** \
# Free trial — бесплатная версия продукта, бесплатный пробный период в приложении или сервисе: кино, музыка, фитнес, медитации, курсы. После пробного периода часть клиентов продолжает пользоваться продуктом (**retention rate** — коэффициент удержания), часть отказывается (**churn rate** — коэффициент оттока).
#
# Также эти два показателя можно использовать для расчёта экономики в любых подписных моделях бизнеса вне зависимости от наличия пробного периода.
#
# Например, каков коэффициент удержания на третий год подписки по сравнению со вторым. Знание этих показателей позволяет привлекать новых пользователей уже сейчас, чтобы потом не было ситуации, когда старые клиенты перестали пользоваться продуктом, а новых клиентов нет.
# ![iЦУАВПКВЦВЦАЫЫЙФУЫПВmage.png](attachment:image.png)

# %% [markdown]
# **Сколько лидов надо привлечь отделу маркетинга, чтобы отдел продаж выполнил план?** \
# Для выполнения KPI отделу продаж в этом квартале необходимо заключить 100 сделок. Мы знаем, что по статистике отдел продаж закрывает 32% сделок.
# Чтобы отдел продаж мог выполнить план, должно быть привлечено достаточное количество лидов на сайт.
# ![iУАПАПВАВЦВФВАУААmage.png](attachment:image.png)

# %% [markdown]
# **Вопрос на оценку эффективности.** \
# Чтобы находить лучшие решения для привлечения клиентов, нам необходимо постоянно работать над рекламными объявлениями, искать УТП, проводить оценку эффективности креативов и текстов объявлений.
#
# Цель — получить большее количество кликов.
# На тесте не обязательно делить трафик пополам. Например, у нас большой бюджет, и мы не хотим слить его, ведь тест может увести нас в минус. Таким образом, новый текст пускаем только на часть трафика, поэтому доли не равны — тестовая группа меньше.
# Но группы должны быть значимые, иначе смысла в тесте нет: нельзя сделать в одной группе 10 000, а в другой — 100.
#
#
# Мы хотим сравнить два текста на баннере и понять, какой текст эффективнее. Для этого мы запустили в продвижение два баннера. Настройки аудитории одинаковые, формат и картинки тоже, разный только текст.
# Какой текст отработал лучше?
#
# ![imВАУЫАУФВЦУЫАФЦВУАage.png](attachment:image.png)
# Второй отработал лучше. Верно. Целью теста было понять, какой баннер отрабатывает лучше в клики. Да, кликов больше в первом случае, но что повлияло на такой результат: текст или то, что мы сделали больше показов (и потратили больше денег)?
#
# На вопрос помогают отвечать именно относительные показатели, например, конверсии (CTR). Если мы увеличим количество показов объявления с текстом 2, то получим 613 кликов.

# %% [markdown]
# # Показатели оценки эффективности отдельных каналов

# %% [markdown]
# ![iауыыЦФАЫФВЦЙФВЫmage.png](attachment:image.png)

# %% [markdown]
# # Построение воронки продаж и расчет метрик

# %% [markdown]
# Теперь мы будем работать с кейсом по продвижению курсов фотографии и применять знания о расчёте метрик и построении воронки продаж.
#
# Умение строить воронку и рассчитывать метрики на каждом этапе – один из ключевых навыков маркетолога.
#
# Воронка продаж позволяет понять, как потенциальный клиент приходит к решению о покупке товаров или услуг, чем он руководствуется, совершая её.
# Зная, какие шаги делает пользователь на пути к принятию решения о покупке, вы сможете контролировать его поведение, ненавязчиво стимулируя интерес и побуждая к приобретению товара или услуги.
#
# Отслеживание метрик на каждом этапе помогает оценивать эффективность внесённых изменений и сравнивать результаты в динамике.

# %% [markdown]
# **Готовы посмотреть на маркетинговую воронку?**
#
# Онлайн-школа планирует к запуску новый продукт — курсы по фотографии. Для начала решено запустить MVP, чтобы протестировать спрос.
# Команда подготовила мини-курсы в записи и пришла к коллегам из отдела маркетинга для настройки, запуска и ведения рекламной кампании.
# Продвигать курсы решили через рекламные объявления у блогеров и в Telegram-каналах.
#
# После небольшого обсуждения определили критерии успешного теста спроса на курс.
# Тест будет успешен, если миникурс купят 100 раз. В нашем случае 100 продаж равно 100 клиентам, т. к. каждый покупает по одному курсу.
# CAC — стоимость привлечения клиента — не должна быть выше 2 000 руб.
# Средний чек — 5 000 руб.
# На создание курса блогера школа потратила 250 000 руб.
# ![imagDSASSFASDFe.png](attachment:image.png)

# %% [markdown]
# CAC=Customer Acquisition Cost

# %% [markdown]
# MVP — Minimum Viable Product — минимально жизнеспособный продукт.
#
# Школа не первый раз продвигает курсы и на основании данных по продажам в этой ценовой категории предполагает, что конверсия в заявку — 3,5%, а из заявки в оплату — 70%.

# %% [markdown]
# Воронка:
#
# 1. Рекламное объявление у блогеров / в Telegram-каналах
# 2. Переход на страницу продукта
# 3. Оформление заказа (заявка)
# 4. Оплата
# Теперь подумайте, на каком этапе какую конверсию будете использовать (3,5% и 70%). Это пригодится в следующем задании.

# %% [markdown]
# **Какой объём трафика необходим для успешного теста?** \
# Онлайн-школа планирует к запуску новый продукт — курсы по фотографии. Для начала решено запустить MVP, чтобы протестировать спрос.
# Команда подготовила мини-курсы в записи и пришла к коллегам из отдела маркетинга для настройки, запуска и ведения рекламной кампании.
# Продвигать курсы решили через рекламные объявления у блогеров и в Telegram-каналах.
#
# После небольшого обсуждения определили критерии успешного теста спроса на курс.
# Тест будет успешен, если миникурс купят 100 раз. В нашем случае 100 продаж равно 100 клиентам, т. к. каждый покупает по одному курсу.
# CAC — стоимость привлечения клиента — не должна быть выше 2 000 руб.
# Средний чек — 5 000 руб.
# На создание курса блогера школа потратила 250 000 руб.

# %% [markdown]
# ![irsrdgewAESRESDage.png](attachment:image.png)

# %% [markdown]
# Сначала считаем заказы. Мы знаем, что конверсия из заказов в покупку — 70%, значит для получения 100 оплат нам нужно, чтобы клиенты сделали 100 / 70% = 142,86 заказа. Округляем до 143 заказов.
#
# Теперь считаем, какой объём трафика необходим, чтобы получить 143 заказа. Мы знаем, что конверсия из трафика в заказ — 3,5%. Трафик = 143 / 3,5% = 4085,71.
# Округляем до 4 086.

# %% [markdown]
# **Сколько максимум можем платить за клики в рекламе?**
# Трафик = количество кликов в нашем случае. Начните расчёты с бюджета.
# Все данные приведены в таблице на скриншоте.
#
# Расчёт предельно допустимых метрик помогает эффективно расходовать бюджет и вовремя отключать убыточные рекламные кампании.
#
# Зная предельные метрики (стоимость клика, стоимость целевого действия, стоимость привлечения пользователя), мы вовремя можем внести корректировки в течение рекламной кампании, отключить неэффективные объявления и перераспределять бюджеты, чтобы не уходить в «минус».

# %% [markdown]
# Для расчёта максимальной суммы за клик в рекламе вам нужно поделить маркетинговый бюджет на тот трафик, который необходимо получить.
#
# Маркетинговый бюджет рассчитываем, умножая CAC на количество клиентов 2 000 × 100 = 200 000.
# Теперь делим бюджет на трафик:
# 200 000 / 4086 = 48,95.
# ![imaDSDFSDSADSFQsadsfge.png](attachment:image.png)

# %% [markdown]
# **Какой будет ROI?**
#
# В расчётах ROI учитываются все расходы.
#
# Все данные приведены в таблице на скриншоте.

# %% [markdown]
# Доход — 500 000 руб.
# Все расходы = 200 000 (маркетинг) + 250 000 (продукт) = 450 000.
# Теперь считаем ROI = ((Доход - Все расходы) / Все расходы) × 100% = 11,11%.
#
# Можно сначала рассчитать прибыль как разницу дохода и расходов, а потом уже ROI.
# ROI = (Прибыль / Все расходы) × 100% = 11,11%.
# ![imagffredwdvdsawsdfestfge.png](attachment:image.png)

# %% [markdown]
# **Что делать дальше с этими данными?**
#
# В этом кейсе мы размещаем рекламу не в рекламном кабинете соцсети. Это не настройка контекстной рекламы, поэтому при расчёте нам придётся опираться на прогнозы, которые озвучивает менеджер канала, на открытые данные или свой опыт работы с этим каналом.
#
# Теперь можно обратиться к маркетологу по партнёрским размещениям и попросить подобрать каналы, в которых стоимость клика будет не выше указанной — 48,95 руб.
#
# Маркетолог анализирует ЦА, на основании анализа подбирает площадки. Дальше маркетолог связывается с владельцами каналов, запрашивает статистику по рекламных интеграциям, отсеивает неподходящие каналы, договаривается о размещении.
#
# (Комментарий эксперта)
#     Нюансы:
#
# Не все пользователи будут оформлять заказ с первого касания. Кто-то будет возвращаться через прямые заходы и поисковые системы.
#
# Большие риски, подобное размещение у партнёров не является рекламой по модели PPC (модель оплаты интернет-рекламы, при которой рекламодатель платит за клики по рекламному объявлению), а значит стоимость клика в реальности может сильно отличаться.

# %% [markdown]
# # Анализ эффективности каналов

# %% [markdown]
# В этой задаче мы будем анализировать эффективность каналов после рекламной кампании.
#
# Проводить анализ рекламных активностей нужно, чтобы вовремя перераспределять бюджеты, вносить коррективы в неэффективные рекламные кампании, делая их эффективными.

# %% [markdown]
# **Ниже вы видите результаты рекламной кампании. Какой метрики не хватает, чтобы оценить эффективность?**
#
# В этом кейсе работаем с большим интернет-магазином, в штате которого есть несколько команд.
#
# Команда маркетинга: специалисты по контекстной рекламе, которые настраивают рекламу в поиске и рекламных сетях, PR-менеджеры, которые размещают статьи о компании и т. д.
#
# Команда витрины: дизайнер интерфейсов, разработчики, backend-разработчики, которые работают над тем, чтобы на сайт подтягивалась актуальная и верная информация о товарах, верстальщики, проектный менеджер, управляющий всей это командой.
#
# Продуктологи в кейсе отвечают именно за монетизацию — работают с экранами и системами оплаты, банками, офферами и т. п. У них в команде тоже есть дизайнеры и разработчики.
# ![imagfgtgweefdsadwre.png](attachment:image.png)

# %% [markdown]
# Все показатели важные, но именно **ROMI** позволит оценить эффективность и сравнить каналы по этому показателю.
#
# В этом кейсе у нас нет информации о маржинальности, поэтому мы оцениваем рекламную кампанию именно с точки зрения возврата инвестиций. То есть мы должны зарабатывать больше, чем тратим на маркетинг.

# %% [markdown]
# **ROMI (Return on Marketing Investment)** — коэффициент возврата маркетинговых инвестиций. Эта метрика показывает рентабельность затрат на маркетинг: рекламу, сайт, SEO-продвижение, email‑рассылки, блог и так далее. ROMI учитывает только маркетинговые затраты, и не включает затраты на производство товара, зарплаты сотрудников, аренду помещения.

# %% [markdown]
# ![imaEFRAsasfadwesfge.png](attachment:image.png)

# %% [markdown]
# **Какие каналы неэффективные?**
#
# Оценить эффективность кампаний поможет ROMI. Нужно постоянно контролировать работу кампаний и каналов, чтобы не тратить маркетинговый бюджет на активности, которые не приносят доход.
#
# Проанализируйте произведенные вами расчёты ROMI в прошлом вопросе.

# %% [markdown]
# Оцениваем ROMI
# ![imRGFDWDFDFSDAWDFSDGBage-2.png](attachment:image-2.png)

# %% [markdown]
# Неэффективны: Яндекс — РСЯ, Одноклассники — Промопост, PR — Статьи

# %% [markdown]
# **Нужно понять, на каких этапах (маркетинг, витрина, оплата) происходит наибольший отвал пользователей в проблемных рекламных каналах. Как мы это поймём?** \
# Выявив узкие места, мы поймём, над чем нужно работать, чтобы вырастить продажи.
#
# Будем смотреть на конверсии и CPC/CPO/CPS на каждом этапе в проблемных каналах и сравнивать их с каналами, которые отрабатывают хорошо

# %% [markdown]
# **Какая проблема у канала Яндекс — РСЯ?**
#
# Рекламная сеть Яндекса (РСЯ) — это система размещения рекламы на сервисах Яндекса и площадках партнёров.
# РСЯ открывает рекламодателям Директа доступ к аудитории более 40 000 площадок: сайтов, мобильных приложений и приложений Smart TV.
# Партнёры РСЯ получают доход за размещение рекламы, а рекламодатели — приток трафика и клиентов.
#
# РСЯ работает так: пользователь заходит на сайт, например, Gismeteo.ru, чтобы посмотреть прогноз погоды. В какой-то части этого сайта появляется рекламный баннер.
# Модель потребления рекламного контента в этом случае сильно отличается от той, что есть в поисковике того же Яндекса.
# В поисковике обычно изначально ищут товар/услугу или информацию, связанную с ними. И рекламные объявления настраивают под эти запросы.
#
# Поэтому в поиске человек больше мотивирован на клик по рекламному объявлению и покупку. А значит сравнивать конверсию и CPC в РСЯ с этими же показателями в поисковом контексте некорректно. Конверсия в клик в РСЯ всегда будет меньше, а управлять CPC можно только через уменьшение CPM.
#
# Так как в этом канале у вас не сходится экономика, нужно решить для себя:
#
# 1. Вы работаете на привлечение пользователей и увеличение продаж, а значит или оптимизируете рекламные объявления, чтобы улучшить показатели конверсии и/или CPC, или отключаете рекламу и перераспределяете бюджет на более эффективные каналы;
# 2. Вы работаете на увеличение охватов и узнавание бренда, а значит исключаете этот канал из отчёта и будете оценивать отдельно по другим метрикам (охватам, top of mind, знанию бренда с подсказкой и без, динамике роста органического трафика).

# %% [markdown]
# ![iWADSFDFDWadrdmage.png](attachment:image.png)
# Конверсия в клик ниже, чем у других каналов, из-за чего стоимость клика значительно выше.
# Но здесь важно разобраться, какая цель изначально была у этого рекламного канала. Чаще всего медийные сети (РСЯ и КМС) используют чтобы привлечь холодный трафик или увеличить знание бренда.

# %% [markdown]
# **Какая проблема у канала PR — Статьи?**
# ![imagfsdgfdsdfsdaese.png](attachment:image.png)
# Цена за клик выше.
#
# Чаще всего под PR понимают статьи не чисто рекламного характера, но рассказывающие о компании, товарах, услугах, проблемах, с которыми сталкиваются люди и которые решает продукт или компания.
#
# По воронке AIDA такие размещения часто направлены на этап первого
# А — Attention. То есть задача этого рекламного канала — работать над «здоровьем бренда». Это предполагает работу с такой информацией и метриками, как знание бренда с подсказкой и без, опыт первой и повторных покупок, лояльность аудитории и готовность рекомендовать бренд, понимание сути бренда и т. д.
#
# Получается, что этот канал не приносит трафик и продажи в моменте, а влияет на эти показатели косвенно и в долгосрочной перспективе. А значит, правильным решением будет исключить этот канал из отчёта и оценивать его эффективность отдельно и по другим метрикам.

# %% [markdown]
# **Каким вы видите идеальный отчёт по метрикам эффективности — ваш идеальный дашборд для этого кейса?**
# Умение выбрать ключевые метрики и показатели для отслеживания – важный навык, который позволяет держать руку на пульсе, вовремя вносить изменения в течение кампаний, чтобы сэкономить рекламный бюджет и расходовать его эффективно.
#
# Здесь подходят все метрики:
# 1. Трафик, заказы, CR, CPO, CPS
# 2. Выручка, средний чек, ROMI
# 3. Плановые показатели, динамика к прошлому периоду

# %% [markdown]
# **В динамике вы можете сравнивать периодами неделя к неделе, месяц к месяцу, год к году. Для чего это нужно?** \
# С плановыми показателями вы сравниваете, чтобы понимать, куда вы двигаетесь и сходится ли ваша экономика. Это помогает ответить на вопросы: насколько вы приросли в трафике, в каких каналах случился этот рост, в каких показателях в воронке вам нужно прирасти, чтобы компенсировать падение в других показателях.
#
# Если, например, ваша текущая конверсия в заявку ниже плановой, то насколько вам нужно прирасти в трафике, чтобы всё-таки добрать нужное количество заявок? Сколько вы ещё можете потратить на привлечение заказов? Заработаете ли вы в этом квартале столько, сколько планировали?
# ![imaцвауывпфвцаупыуЦВЕge.png](attachment:image.png)
#
# Крайне важно анализировать рекламные активности и декомпозировать данные, чтобы находить неэффективные рекламные каналы, источники и вовремя их отключать. Корректировать кампании с потенциалом для улучшения их течения, следить за плановыми метриками и не выходить за рамки бюджета. Вовремя перераспределять бюджет, чтобы получать необходимое количество трафика и заявок.
#
# Прежде чем отключать кампании и каналы, нужно установить, какую цель они должны были достичь, и участвуют ли они в пути до конверсии. Возможно, канал не является заключительным в пути пользователя к покупке, но участвует в цепочке и влияет на продажи косвенно.

# %% [markdown]
# # Как метрика обрабатывает данные

# %% [markdown]
# Следить за посещаемостью сайта и оценивать качество его работы помогают системы веб-аналитики. Они различаются набором возможностей, скоростью обработки данных и, конечно, интерфейсами, но в целом устроены похожим образом.
#
# Обычно аналитические сервисы состоят из трёх частей.
# * Первая — счётчик. На сайте размещается специальный код, и каждый раз, когда страница загружается или пользователь совершает на ней какие-то действия, счётчик отправляет сообщение в базу данных системы. * Это вторая часть сервиса, там информация систематизируется и обрабатывается.
# * Третья часть — интерфейс, в котором представлены обработанные данные по тому или иному сайту и отчёты на основе этих данных — в виде таблиц и графиков.

# %% [markdown]
# **Метрика**, как и все системы веб-аналитики, оперирует несколькими базовыми понятиями:
# * *«Посетитель»* — пользователь, зашедший на сайт. Когда он приходит впервые, в его браузер записывается уникальный идентификатор, по которому счётчик Метрики узнаёт его в следующий раз.
# * *«Просмотр»* — каждое обращение посетителя к сайту, включая простое обновление страницы.
# * *«Визит»* — один сеанс работы пользователя с сайтом. Визит начинается, когда посетитель попадает на сайт, и заканчивается, если он не предпринимает там никаких действий в течение определённого времени — по умолчанию это 30 минут. Визит может включать в себя множество просмотров разных страниц. В базе Метрики хранятся данные как об отдельных просмотрах, так и о визитах.

# %% [markdown]
# **Сбор данных** \
# Когда посетитель переходит на сайт со счётчиком Метрики — из поисковой системы, социальной сети, с рекламного баннера или просто введя адрес в адресной строке, — его браузер загружает код страницы. В этот момент счётчик отправляет в Метрику данные:
# * сам факт загрузки страницы
# * уникальный идентификатор посетителя
# * адрес страницы, с которой он пришёл
# * название и версию браузера и операционной системы и так далее.
#
# **Метрика не знает ничего о конкретном человеке с именем и фамилией, который совершает в интернете конкретные действия**. Идентификатор посетителя и все остальные его параметры становятся частью обезличенной статистики — цифрами, которые помогают пользователю Метрики развивать свой сайт.
#
# Пока посетитель находится на сайте, счётчик продолжает собирать статистику и отправлять её Метрике. Каждый раз, когда человек открывает какую-нибудь страницу, счётчик регистрирует просмотр. Если он длится дольше 15 секунд, система снова получает сообщение — о том, что просмотр продолжается. Если же человек зашёл только на одну страницу сайта и пробыл там меньше 15 секунд, счётчик отправляет сообщение об отказе. Процент отказов помогает владельцу сайта узнать, сколько посетителей не заинтересовались страницей или попали туда случайно.
#
# Счётчик фиксирует прокручивание страницы, движения мыши и клики по кнопкам и ссылкам (отчёт об этих действиях владелец сайта может посмотреть в отдельном разделе Метрики — Вебвизоре). Также он сообщает, совершил ли посетитель важные для владельца сайта действия — например, зарегистрировался на форуме, кликнул по рекламному баннеру или оформил заказ в интернет-магазине.
#
# Для системы статистики один человек может стать несколькими посетителями. Например, если он зайдёт на сайт с двух разных устройств, из разных браузеров или из одного браузера, но после его переустановки. Бывает и наоборот: Метрика может считать одним посетителем семью из пяти человек, если все её члены пользуются одним браузером.

# %% [markdown]
# **Отчёты** \
# В базе данных Метрики хранятся самые разнообразные данные о посещаемости сайта. Владелец составляет на их основе отчёты и смотрит результаты его работы в разных срезах — временных, географических, возрастных или даже сразу нескольких.
#
# Например, чтобы понять, хорошо ли в целом сработала ваша рекламная кампания, можно посмотреть в Метрике общую информацию — увеличилось ли количество посещений, из каких источников приходили люди и как изменилась глубина просмотра. А можно углубиться в детали и попытаться ответить на более конкретный вопрос. Допустим, у вас есть сервис для молодых жителей Санкт-Петербурга и вы хотите проверить, удобен ли его новый мобильный интерфейс. Метрика позволяет узнать, много ли владельцев смартфонов в возрасте от 18 до 34 лет просмотрело больше двух страниц вашего сайта и много ли было отказов, а вам останется только сделать выводы.
#
# Все отчёты составляются сразу: владелец сайта указывает, что хочет посмотреть, и система сразу же извлекает данные из базы и показывает результат — учитывая даже тех посетителей, которые были на сайте только что.
#
# ![imaцуаыЦФАУФВЦФЫАВge.png](attachment:image.png)

# %% [markdown]
# **Хранение и обработка данных (ClickHouse)** \
# Поскольку отчёты создаются в реальном времени, их структура становится известна только в тот момент, когда владелец сайта делает через интерфейс Метрики запрос для получения отчёта. Структура отчёта может быть практически любой, а составляется он за долю секунды. Чтобы владелец сайта получал актуальную и полную информацию, нужно постоянно собирать данные о посещаемости и уметь тут же их обрабатывать. Для этого в 2012 году Яндекс разработал свою систему управления базами данных (СУБД) — **ClickHouse**.
#
# Есть два варианта подготовки данных для аналитических отчётов. В первом, с которым раньше работала Метрика, данные агрегируются предварительно, и на их основе составляется фиксированный набор отчётов. Это позволяет загружать отчёты достаточно быстро, но ограничивает гибкость аналитики: пользователь может получить только один из набора предусмотренных отчётов. Другой вариант — хранить поступающие в систему события без предварительной агрегации, а вычисления выполнять в онлайне — в тот момент, когда пользователь загружает отчёт. Это сильно расширяет аналитические возможности, но накладывает очень серьёзные требования на скорость обработки данных.
#
# Существует два основных типа СУБД — строковые и столбцовые. Они отличаются организацией хранения данных на физическом уровне. Большинство известных СУБД строковые — в них данные, которые в таблице находятся в разных ячейках одной строки, хранятся рядом, друг за другом. Такие СУБД хорошо подходят, например, для обработки транзакций, так как позволяют быстро обновлять отдельные строки в базе данных. Для аналитических запросов, когда необходимы только данные из нескольких столбцов в большом массиве строк, строковые СУБД подходят хуже. При обработке таких запросов необходимо прочитать и отбросить значения всех остальных столбцов — в том числе в данном случае ненужных. На это уходит время.
#
# ![ChessUrl](https://avatars.mds.yandex.net/get-yablogs/38241/file_1449568862132/orig "1")
#
# В столбцовых СУБД, к которым как раз и относится ClickHouse, данные хранятся в порядке столбцов: значения, относящиеся к одному столбцу, расположены рядом. В Яндекс.Метрике мы храним события (визиты, просмотры и т. п.) в нескольких таблицах, где строки — это всё те же события, а столбцы — их параметры. Такая структура СУБД позволяет увеличивать количество параметров событий без потери производительности. Например, если нам нужно получить отчёт по количеству уникальных посетителей в разрезе регионов, достаточно прочитать с диска только два столбца.
#
# ![ChessUrl](https://avatars.mds.yandex.net/get-yablogs/38241/file_1449568944223/orig "2")
#
# В октябре 2015 года объём данных Метрики только для веб-сайтов составил 10,65 триллиона строк. В наиболее крупной таблице содержится 349 столбцов. Каждый раз, когда владелец сайта открывает страницу в Метрике, в ClickHouse отправляется несколько запросов. Всего база данных получает примерно 2000 запросов в секунду; пиковая скорость обработки данных превышает два терабайта в секунду.
#
# ClickHouse легко масштабируется: добавление новых серверов происходит без перестройки кластера. Один запрос может обрабатываться с использованием вычислительной мощности всех доступных серверов, поэтому данные обрабатываются очень быстро. Другая полезная особенность ClickHouse — отказоустойчивость: даже если какие-то серверы выходят из строя, система продолжает работать. Для этого данные реплицируются в географически распределённых дата-центрах.
#
# ClickHouse позволяет серьёзно уменьшить затраты на хранение и обработку данных. Данные хранятся в нём по столбцам, и за счёт этого их можно эффективно сжимать. В ClickHouse реализован векторный движок выполнения запросов: данные не только хранятся, но и обрабатываются по столбцам, что позволяет оптимальным образом использовать процессор и память. Данные на диске переупорядочиваются (например, по сайту и дате), чтобы для составления отчёта достаточно было прочитать с диска лишь небольшой диапазон строк. Одновременно с этим ClickHouse позволяет добавлять в таблицу новые данные в реальном времени.
#
# Система ClickHouse, разработанная в команде Метрики и для её нужд, оказалась полезна и для других задач Яндекса. В том числе СУБД используется в Маркете, рекламных технологиях, системе мониторинга серверов и внутренней бизнес-аналитике. ClickHouse сравнительно прост для изучения, так как для запросов используется язык SQL.

# %% [markdown]
# # Настройка и просмотр отчета

# %% [markdown]
# Отчеты содержат статистическую информацию о сайте и делятся на **стандартные (предложенные сервисом)** и **пользовательские**.
#
# Отчет Метрики является конструктором. То есть его можно настроить: добавить или убрать группировку или метрику, добавить цель или сегмент. Основа отчета — это набор группировок. Группировка, которая указана первой в списке, определяет смысл отчета. Если изменить набор группировок или их порядок, то смысл отчета изменится, хотя название останется прежним.
#
# Например, Отчет «Директ, сводка» по умолчанию строится по группировкам, связанным с Директом (Кампания Яндекс Директа и пр.). Если добавить в отчет группировку Дата визита и переместить ее в начало списка, то отчет перестроится — отобразит статистику по всем источникам, из которых были совершены визиты на сайт.

# %% [markdown]
# ## Настройка отчета

# %% [markdown]
# ![imagауывпкыцйцвыпвкцуфвпатe-2.png](attachment:image-2.png)

# %% [markdown]
# 1. **Виды диаграмм** \
#     По умолчанию данные отображаются в виде линий. Они наглядно представляют динамику показателей. Вы можете использовать наиболее подходящий вид диаграммы для выбранного отчета:
#     * Линии — изменения абсолютных значений измеряемых величин во времени.
#     * Круговая — распределение величин по группам.
#     * Области — динамика величин (их значения суммируются). График в каждый момент времени показывает суммарное количество визитов для указанных в легенде величин.
#     * Колонки — изменение соотношений исследуемых величин во времени.
# 2. **Сегментация** \
#     Сегментация позволяет сформировать отчет по визитам, которые удовлетворяют необходимым вам условиям. Например, можно из данных отчета Источники, сводка выделить источники, из которых пришли только пользователи планшетов. Подробно см. раздел Сегментация данных.
# 3. **Выборка** \
#     Если для формирования отчета требуется большое количество данных, то сбор информации может занять продолжительное время. Поэтому для более быстрого формирования отчета сервис использует только часть данных (например, 10%). Чтобы изменить эту величину, в Метрике на странице отчета нажмите кнопку Выборка и переместите бегунок в нужную область — Быстрее или Точнее. Подробно см. в разделе Семплирование.
#
#     При переходе в другой отчет настройка сохраняется. Информация об этом появляется внизу экрана. Вы можете оставить или сбросить ее.
# 4. **Период отчета** \
#     Вы можете выбрать календарный период времени, за который будет построен отчет. По умолчанию выбран месяц. Также можно задать интервал дат, нажав элемент.
# 5. **Детализация данных по времени** \
#     На диаграммах «Линии» и «Области» данные отображаются с разбивкой периода на отрезки времени. По умолчанию выбрано значение авто. Оно устанавливает интервал с учетом выбранного периода времени и количества данных, достаточного для этого периода. Вы можете детализировать временной период по минутам, часам, дням, неделям и месяцам.
# 6. **Модели атрибуции** \
#     Помогут верно определить источник перехода посетителя на сайт — чтобы рассчитать конверсию по созданной цели. Подробно см. в разделе Модели атрибуции.
# 7. **Отображение данных в таблице** \
#     Все показатели объединяются в группы по некоторым признакам (группировкам: по операционной системе, ее версии и т. д.). Признаки отображаются слева в виде списка строк:
#     * Линейный список
#     * Древовидный список (постепенно раскрывает структуру)
# 8. **Группировки и метрики** \
#     Каждый отчет содержит показатели (метрики), объединенные в группы (группировки). Подробно см. раздел Получение и отображение данных. Метрики.
#     Чтобы сформировать отчет, нажмите кнопку Группировки или Метрики. В появившемся окне выберите параметры, по которым хотите построить отчет. Они отобразятся в правой части окна.\
#     При выборе группировки рядом с ней появляется значок . Он указывает, что хотя бы одна группировка из данного блока используется в отчете.\
#        ![imageЫМАЫМВИАЫАВАЫВ.png](attachment:image.png)
# 9. **Примечания на графике** \
#     Примечания помогают отслеживать важные события и связанные с ними изменения статистики сайта. Вы можете создавать свои примечания и использовать системные — предустановленные Яндекс Метрикой. К системным примечаниям относятся:
#     ![imaЦУАКВППАУФЦВВКПУЦУФВАВКge-2.png](attachment:image-2.png)
# 10. **Достоверность данных** \
#     Метрика предоставляет много цифр по всевозможным аспектам работы вашего сайта и все эти цифры точны с точки зрения методики их расчета. Но с точки зрения анализа работы сайта это не всегда так: например, если на сайт заходил один посетитель и смотрел страницы 20 минут, формально верно, что среднее время посещения сайта — 20 минут. Но с точки зрения здравого смысла это не так: делать какие-то выводы о сайте на основании этого визита нельзя.
#
#     Сервис дает возможность скрывать строки отчета, которые содержат такую недостоверную информацию. Подробно см. в разделе Статистическая достоверность данных.
# 11. **Выбор цели** \
#     При выборе из списка созданной ранее цели, данные отчета обновляются с учетом этой цели. В списке цели разделены по назначению: конверсионные и ретаргетинговые. Подробно см. в разделе Что такое цели. Типы целей.
#     ![imageВЫАВПАУФЫАКВКАКВП-3.png](attachment:image-3.png)
# 12. **Уточнение числовых показателей** \
#     Яндекс Метрика позволяет задать числовое значение, относительно которого будут отображены статистические величины. Например, показать в отчете информацию по отказам со значением больше 50%. Чтобы отфильтровать значения, нажмите значок . При этом в отчете будут показаны только те строки (значения группировок), для которых значения метрик соответствуют заданному условию.
#     ![imaУАЦУВЙВЦЫАВФЫАВВУЫge-4.png](attachment:image-4.png)
# 13. **Отображение данных на диаграмме** \
#     По умолчанию на диаграмме отображаются значения того показателя, по которому отсортированы данные. Вы можете построить диаграмму по любому другому показателю, который доступен в отчете, нажав значок . После этого диаграмма перестраивается.
# 14. **Сортировка данных по показателю** \
#     По умолчанию данные отчета сортируются по первому показателю (например, по визитам). Вы можете изменить сортировку, нажав на тот показатель, который считаете наиболее важным.
# 15. **Скрытие диаграммы** \
#     Вы можете скрыть отображение данных на диаграмме. Настройка сохраняется при переходе между отчетами.
# 16. **Валюта** \
#     Валюта отображается, если отчет содержит информацию о денежных средствах, например, доходе электронной коммерции или расходах на рекламу. Также валюта отображается, если вы передаете доход по цели.\
#     В списке доступны валюты, в которых были переданы данные в Метрику. При выборе валюты значения метрик дохода и расхода пересчитываются в соответствии с курсом конвертации, который был днем ранее совершения расхода или дохода.\
#     Для конвертации используется курс, который предоставляют больше 15 источников, включая Европейский центральный банк. Конвертация в валюты EUR и RUB происходит относительно USD.
# 17. **Отслеживания доли роботов в трафике** \
#     Метрика определяет роботов, которые посещают сайт. Фильтрация роботов помогает получать точные значения метрик. Например, показателя отказов, времени на сайте и глубины просмотра. По умолчанию в отчетах учитываются данные без визитов роботов.\
#     При этом действует сегмент Роботность: С роботами. Если вы удалите его, данные пересчитаются с учетом роботных визитов.\
#     Чтобы увидеть долю роботов, используйте метрику Роботность. Чтобы ее добавить, в отчете в настройке Данные выберите с роботами. После этого включится опция Метрика Роботность в отчетах — метрика появится в таблице данных.
